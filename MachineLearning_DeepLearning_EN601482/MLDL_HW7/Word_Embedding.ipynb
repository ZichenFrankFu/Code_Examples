# %% [markdown]
# # Word Embeddings
#
# In this notebook, you will implement 2 algorithms for learning word embeddings. You will use these algorithms to measure semantic similarity between words.

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

## Standard Library
import random
from string import punctuation
from collections import Counter

## External Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_distances
from sklearn.datasets import fetch_20newsgroups
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')
import gensim.downloader

# PyTorch Modules: see http://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)
print("GPU Available:", torch.cuda.is_available())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# GPU Available: True

# %%
## Simple Plotting Utility
def showPlot(title, *args):
    plt.figure()
    fig, ax = plt.subplots()
    for a in args:
      _ = ax.plot(a)
    _ = ax.set_title(title)

# %%
def tokenize(text):
    """
    Simple tokenizer (sentences and then words)
    """
    sentences = sent_tokenize(text)
    examples = []
    for sentence in sentences:
        sentence = "".join(char for char in sentence if char not in punctuation)
        sentence = "".join(char for char in sentence if not char.isdigit())
        sentence = sentence.lower()
        tokens = word_tokenize(sentence)
        examples.append(tokens)
    return examples

tokenize("Why, hello there! What's your name?")
# Out:
# [['why', 'hello', 'there'], ['whats', 'your', 'name']]

# %% [markdown]
# ### Data
#
# We provide two datasets. Use the small dataset to develop your algorithms and test semantic similarity at the end of the notebook. Use the larger dataset once your models are developed to get a sense for the scalability of your approaches.
#
# Please include visualizations of the train/test loss for both datasets. For the small dataset, please train your models for 1000 epochs. For the large dataset, please train your models for at least 100 epochs.

# %%
# Text is lightly adapted (removing punctuation and possesives) from The Raven by Edgar Allan Poe
text_small = [""" Once upon a midnight dreary while I pondered weak and weary
 Over many a quaint and curious volume of forgotten lore
 While I nodded nearly napping suddenly there came a tapping
 As of some one gently rapping rapping at my chamber door
 This is some visiter I muttered tapping at my chamber door
                          Only this and nothing more

 Ah distinctly I remember it was in the bleak December
 And each separate dying ember wrought its ghost upon the floor
 Eagerly I wished the morrow vainly I had sought to borrow
 From my books surcease of sorrow sorrow for the lost Lenore
 For the rare and radiant maiden whom the angels name Lenore
                          Nameless here for evermore

 And the silken sad uncertain rustling of each purple curtain
 Thrilled me filled me with fantastic terrors never felt before
 So that now to still the beating of my heart I stood repeating
 This is some visiter entreating entrance at my chamber door
 Some late visiter entreating entrance at my chamber door
                          This it is and nothing more

 Presently my soul grew stronger hesitating then no longer
 Sir said I or Madam truly your forgiveness I implore
 But the fact is I was napping and so gently you came rapping
 And so faintly you came tapping tapping at my chamber door
 That I scarce was sure I heard you here I opened wide the door
                          Darkness there and nothing more

 Deep into that darkness peering long I stood there wondering fearing
 Doubting dreaming dreams no mortal ever dared to dream before
 But the silence was unbroken and the darkness gave no token
 And the only word there spoken was the whispered word Lenore
 This I whispered and an echo murmured back the word Lenore
                          Merely this and nothing more

 Back into the chamber turning all my soul within me burning
 Soon I heard again a tapping somewhat louder than before
 Surely said I surely that is something at my window lattice
 Let me see then what thereat is and this mystery explore
 Let my heart be still a moment and this mystery explore
                          This is the wind and nothing more

 Open here I flung the shutter when with many a flirt and flutter
data = fetch_20newsgroups(subset="test", ## Choose Test Since Full Dataset Will Take Significant Training Time
                          remove=("headers","footers","quotes"),
                          data_home="./data/",
                          download_if_missing=True,
                          shuffle=False)

## Isolate Data
text_large = data.data
labels = data.target

## Show Sample Newsgroups Data
show = lambda i: print(text_large[i], "\n", tokenize(text_large[i]))
show(30)
# Out:
# It wasn't Jesus who changed the rules of the game (see quote above),
# it was Paul.
#
# Cheers,
# Kent
#
#  [['it', 'wasnt', 'jesus', 'who', 'changed', 'the', 'rules', 'of', 'the', 'game', 'see', 'quote', 'above', 'it', 'was', 'paul'], ['cheers', 'kent']]

# %%
## Tokenize Data (We Recommend Developing your model using text_small first)
documents = list(map(tokenize, text_small))
# documents = list(map(tokenize, text_large))

## Flatten Sentences
documents = [tokens for d in documents for tokens in d]
print("Dataset Size:", len(documents))
# Out:
# Dataset Size: 1

# %%
## Choose Frequency and Top Word Removal (Should Change This Depending on the Dataset)
MIN_FREQ = 0
RM_TOP = 0

## Get Vocabulary
vocab = [t for document in documents for t in document]
vocab_counts = Counter(vocab)
stopwords = set([s[0] for s in vocab_counts.most_common(RM_TOP)])
vocab = set([v for v in set(vocab) if vocab_counts[v] >= MIN_FREQ and v not in stopwords] + ["EOS"])
vocab_size = len(vocab)
print("Vocab Size:", vocab_size)

# Build a dictionary so that each word in vocabualary is assigned a number and
# and we can map each number back to the word
w2i = {w: i for i, w in enumerate(sorted(vocab))}
i2w = {i: w for i, w in enumerate(sorted(vocab))}
# Out:
# Vocab Size: 435

# %%
## Update The Documents with OOV Token
documents = [list(filter(lambda token: token in vocab, document)) for document in documents]

## Sample Training And Test Documents
np.random.seed(1)
documents_train = documents_test = documents
if len(documents) > 1:
    train_ind, test_ind = train_test_split(list(range(len(documents))))
    documents_train = [documents[t] for t in train_ind]
    documents_test = [documents[t] for t in test_ind]

# %% [markdown]
# ![Continuous bag of words vs. skipgram model](https://raw.githubusercontent.com/jojonki/word2vec-pytorch/master/word2vec.PNG)
#
# Image from https://github.com/jojonki/word2vec-pytorch

# %% [markdown]
# ## CBOW Implementation
#
# Fill in the TODOs below.

# %%
## Choose Context Size
CONTEXT_SIZE = 2

# Tuple of an array of words (the context) to a word (the target)
def create_cbow_dataset(documents, context_size):
    data = []
    for document in documents:
        ## Pad the sentence
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        ## Get Context Tokens
        for i in range(context_size, len(document) - context_size):
            target = document[i]
            before_ctx = []
            after_ctx = []
            for j in range(1,context_size+1):
                before_ctx.append(document[i - j])
                after_ctx.append(document[i + j])
            context = before_ctx + after_ctx
            data.append((context, target))
    return data

## Generate Datasets
cbow_train = create_cbow_dataset(documents_train, context_size=CONTEXT_SIZE)
cbow_test = create_cbow_dataset(documents_test, context_size=CONTEXT_SIZE)

## Show Samples
print('cbow train samples')
for i in range(5):
    print(cbow_train[i])
print("total train samples", len(cbow_train))
print("total test samples", len(cbow_test))
# Out:
# cbow train samples
# (['EOS', 'EOS', 'upon', 'a'], 'once')
# (['once', 'EOS', 'a', 'midnight'], 'upon')
# (['upon', 'once', 'midnight', 'dreary'], 'a')
# (['a', 'upon', 'dreary', 'while'], 'midnight')
# (['midnight', 'a', 'while', 'i'], 'dreary')
# total train samples 1090
# total test samples 1090

# %%
## Example of the Dataset Generator
create_cbow_dataset([["hello","there","my","friend"]], 2)
# Out:
# [(['EOS', 'EOS', 'there', 'my'], 'hello'),
#  (['hello', 'EOS', 'my', 'friend'], 'there'),
#  (['there', 'hello', 'friend', 'EOS'], 'my'),
#  (['my', 'there', 'EOS', 'EOS'], 'friend')]

# %%
## Helper Function to Construct Batches of Examples
def get_cbow_batches(data, batch_size):
    """
    Generate batches of data for training CBOW Model
    """
    indices = np.arange(len(data))
    np.random.shuffle(indices)
    current_batch = []
    for i, indice in enumerate(indices):
        context, target = data[indice]
        ctx_idxs = [w2i[w] for w in context]
        ctx_var = torch.LongTensor(ctx_idxs)
        current_batch.append((ctx_var, torch.LongTensor([w2i[target]])))
        if current_batch and len(current_batch) % batch_size == 0 or i == len(indices) - 1:
            batch_context = torch.stack([v[0] for v in current_batch])
            batch_target = torch.stack([v[1] for v in current_batch])
            current_batch = []
            yield batch_context, batch_target

# %%
# Simple 3 layer network to map target word to an array of probabilities for
# each word being in its context
# Note that the first layer is a special layer - an embedding layer
# It maps the one-hot encoded vocabulary to a vector of a fixed size
class CBOW(nn.Module):
    def __init__(self, vocab_size, embd_size, context_size, hidden_size):
        super(CBOW, self).__init__()
        #TODO implement layers show in the picture above
        self.context_size = context_size
        self.embd_size = embd_size

        self.embedding = nn.Embedding(vocab_size, embd_size)
        self.layer1 = nn.Linear(2*context_size*embd_size, hidden_size)
        self.layer2 = nn.Linear(hidden_size, vocab_size)



    def forward(self, inputs):
        out = self.embedding(inputs)
        out = out.view(-1, 2 * self.context_size * self.embd_size)
        out = F.relu(self.layer1(out))
        out = self.layer2(out)
        out = F.log_softmax(out)
        return out

# %%
def train_cbow(train_data,
               test_data,
               model=None,
               n_epoch=5,
               embd_size=100,
               learning_rate=0.01,
               context_size=CONTEXT_SIZE,
               batch_size=1000,
               hidden_size=64,
               print_every=5000,
               random_seed=1):
    """

    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Batch size
    batch_size = min(batch_size, len(train_data))
    ## Initialize New Model if Not Using Existing
    if model is None:
        model = CBOW(vocab_size, embd_size, context_size, hidden_size)
    ## GPU
    gpu_avail = torch.cuda.is_available()
    if gpu_avail:
        model = model.cuda()
    ## Show the Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate loss function
    loss_fn = nn.CrossEntropyLoss()
    ## Cache for Loss Values
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        model.train()
        counter = 0
        for batch, (context, target) in enumerate(get_cbow_batches(train_data, batch_size)):
            ##TODO implement training procedure for CBOW
            counter += 1
            target = target[:, 0]

            if gpu_avail:
                context, target = context.cuda(), target.cuda()

            optimizer.zero_grad()

            outputs = model(context)
            loss = loss_fn(outputs, target)


            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if print_every is not None and (batch + 1) % print_every == 0:
                print("Epoch {} || batch {} || Loss: {:.4f}".format(epoch+1, batch+1, total_loss / (batch+1)))

        model.eval()
        ##TODO Compute Loss on Test and Training Data
        train_loss = total_loss / counter
        test_loss = 0
        with torch.no_grad():
          counter = 0
          for context, target in get_cbow_batches(test_data, batch_size):
              counter += 1
              target = target[:, 0]

              if gpu_avail:
                  context, target = context.cuda(), target.cuda()

              outputs = model(context)
              loss = loss_fn(outputs, target)
              test_loss += loss.item()
        test_loss = test_loss/counter

        print("Epoch {}/{} || Train Loss: {:.4f} || Test Loss: {:.4f}".format(epoch+1, n_epoch, train_loss, test_loss))
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete.")
    return model, losses, test_losses

## Train Model
cbow_model, cbow_losses, cbow_test_losses = train_cbow(cbow_train,
                                     cbow_test,
                                     model=None,
                                     n_epoch=5000,
                                     embd_size=300,
                                     context_size=CONTEXT_SIZE,
                                     batch_size=1000,
                                     learning_rate=0.005,
                                     hidden_size=128,
                                     print_every=100)
# Out:
# CBOW(
#   (embedding): Embedding(435, 300)
#   (layer1): Linear(in_features=1200, out_features=128, bias=True)
#   (layer2): Linear(in_features=128, out_features=435, bias=True)
# )
# <ipython-input-14-e0a2613bcaff>:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.log_softmax(out)
# Streaming output truncated to the last 5000 lines.
# Epoch 2/5000 || Train Loss: 6.0943 || Test Loss: 6.0836
# Epoch 3/5000 || Train Loss: 6.1067 || Test Loss: 6.0996
# Epoch 4/5000 || Train Loss: 6.1007 || Test Loss: 6.0851
# Epoch 5/5000 || Train Loss: 6.1300 || Test Loss: 6.0839
# Epoch 6/5000 || Train Loss: 6.0815 || Test Loss: 6.0526
# Epoch 7/5000 || Train Loss: 6.0739 || Test Loss: 6.0684
# Epoch 8/5000 || Train Loss: 6.0675 || Test Loss: 6.0962
# Epoch 9/5000 || Train Loss: 6.0773 || Test Loss: 6.0960
# Epoch 10/5000 || Train Loss: 6.0737 || Test Loss: 6.0738
# Epoch 11/5000 || Train Loss: 6.0771 || Test Loss: 6.0707
# Epoch 12/5000 || Train Loss: 6.0829 || Test Loss: 6.0580
# Epoch 13/5000 || Train Loss: 6.0765 || Test Loss: 6.0641
# Epoch 14/5000 || Train Loss: 6.0846 || Test Loss: 6.0620
# Epoch 15/5000 || Train Loss: 6.0588 || Test Loss: 6.0663
# Epoch 16/5000 || Train Loss: 6.0593 || Test Loss: 6.0234
# Epoch 17/5000 || Train Loss: 6.0331 || Test Loss: 6.0344
# Epoch 18/5000 || Train Loss: 6.0555 || Test Loss: 6.0370
# Epoch 19/5000 || Train Loss: 6.0603 || Test Loss: 6.0454
# Epoch 20/5000 || Train Loss: 6.0341 || Test Loss: 6.0355
# Epoch 21/5000 || Train Loss: 6.0256 || Test Loss: 6.0384
# Epoch 22/5000 || Train Loss: 6.0450 || Test Loss: 6.0256
# Epoch 23/5000 || Train Loss: 6.0527 || Test Loss: 6.0463
# Epoch 24/5000 || Train Loss: 6.0415 || Test Loss: 6.0313
# Epoch 25/5000 || Train Loss: 6.0449 || Test Loss: 6.0265
# Epoch 26/5000 || Train Loss: 6.0228 || Test Loss: 6.0225
# Epoch 27/5000 || Train Loss: 6.0165 || Test Loss: 5.9990
# Epoch 28/5000 || Train Loss: 6.0252 || Test Loss: 6.0086
# Epoch 29/5000 || Train Loss: 6.0123 || Test Loss: 6.0184
# Epoch 30/5000 || Train Loss: 6.0299 || Test Loss: 6.0105
# Epoch 31/5000 || Train Loss: 5.9999 || Test Loss: 6.0176
# Epoch 32/5000 || Train Loss: 6.0144 || Test Loss: 6.0026
# Epoch 33/5000 || Train Loss: 5.9947 || Test Loss: 6.0147
# Epoch 34/5000 || Train Loss: 6.0058 || Test Loss: 5.9998
# Epoch 35/5000 || Train Loss: 6.0040 || Test Loss: 5.9862
# Epoch 36/5000 || Train Loss: 5.9877 || Test Loss: 5.9868
# Epoch 37/5000 || Train Loss: 6.0028 || Test Loss: 5.9816
# Epoch 38/5000 || Train Loss: 5.9792 || Test Loss: 5.9933
# Epoch 39/5000 || Train Loss: 5.9786 || Test Loss: 5.9524
# Epoch 40/5000 || Train Loss: 5.9581 || Test Loss: 5.9797
# Epoch 41/5000 || Train Loss: 5.9827 || Test Loss: 5.9895
# Epoch 42/5000 || Train Loss: 5.9617 || Test Loss: 5.9680
# Epoch 43/5000 || Train Loss: 5.9783 || Test Loss: 5.9933
# Epoch 44/5000 || Train Loss: 5.9517 || Test Loss: 5.9650
# Epoch 45/5000 || Train Loss: 5.9745 || Test Loss: 5.9660
# Epoch 46/5000 || Train Loss: 5.9658 || Test Loss: 5.9756
# Epoch 47/5000 || Train Loss: 5.9508 || Test Loss: 5.9659
# Epoch 48/5000 || Train Loss: 5.9378 || Test Loss: 5.9640
# Epoch 49/5000 || Train Loss: 5.9509 || Test Loss: 5.9585
# Epoch 50/5000 || Train Loss: 5.9596 || Test Loss: 5.9500
# Epoch 51/5000 || Train Loss: 5.9481 || Test Loss: 5.9460
# Epoch 52/5000 || Train Loss: 5.9142 || Test Loss: 5.9346
# Epoch 53/5000 || Train Loss: 5.9407 || Test Loss: 5.9448
# Epoch 54/5000 || Train Loss: 5.9582 || Test Loss: 5.9607
# Epoch 55/5000 || Train Loss: 5.9128 || Test Loss: 5.9098
# Epoch 56/5000 || Train Loss: 5.9384 || Test Loss: 5.9139
# Epoch 57/5000 || Train Loss: 5.9516 || Test Loss: 5.9363
# Epoch 58/5000 || Train Loss: 5.9519 || Test Loss: 5.9119
# Epoch 59/5000 || Train Loss: 5.9179 || Test Loss: 5.9276
# Epoch 60/5000 || Train Loss: 5.9139 || Test Loss: 5.9232
# Epoch 61/5000 || Train Loss: 5.9013 || Test Loss: 5.8983
# Epoch 62/5000 || Train Loss: 5.9129 || Test Loss: 5.9308
# Epoch 63/5000 || Train Loss: 5.9185 || Test Loss: 5.8825
# Epoch 64/5000 || Train Loss: 5.9109 || Test Loss: 5.9248
# Epoch 65/5000 || Train Loss: 5.9143 || Test Loss: 5.9094
# Epoch 66/5000 || Train Loss: 5.9032 || Test Loss: 5.8922
# Epoch 67/5000 || Train Loss: 5.9127 || Test Loss: 5.9020
# Epoch 68/5000 || Train Loss: 5.9003 || Test Loss: 5.9182
# Epoch 69/5000 || Train Loss: 5.8901 || Test Loss: 5.8989
# Epoch 70/5000 || Train Loss: 5.9135 || Test Loss: 5.8857
# Epoch 71/5000 || Train Loss: 5.9090 || Test Loss: 5.8904
# Epoch 72/5000 || Train Loss: 5.8838 || Test Loss: 5.8942
# Epoch 73/5000 || Train Loss: 5.8843 || Test Loss: 5.8960
# Epoch 74/5000 || Train Loss: 5.8834 || Test Loss: 5.8889
# Epoch 75/5000 || Train Loss: 5.8803 || Test Loss: 5.8948
# Epoch 76/5000 || Train Loss: 5.8536 || Test Loss: 5.8773
# Epoch 77/5000 || Train Loss: 5.8844 || Test Loss: 5.8688
# Epoch 78/5000 || Train Loss: 5.8626 || Test Loss: 5.8551
# Epoch 79/5000 || Train Loss: 5.8467 || Test Loss: 5.8509
# Epoch 80/5000 || Train Loss: 5.8774 || Test Loss: 5.8670
# Epoch 81/5000 || Train Loss: 5.8857 || Test Loss: 5.8710
# Epoch 82/5000 || Train Loss: 5.8591 || Test Loss: 5.8612
# Epoch 83/5000 || Train Loss: 5.8627 || Test Loss: 5.8430
# Epoch 84/5000 || Train Loss: 5.8803 || Test Loss: 5.8286
# Epoch 85/5000 || Train Loss: 5.8633 || Test Loss: 5.8227
# Epoch 86/5000 || Train Loss: 5.8540 || Test Loss: 5.8380
# Epoch 87/5000 || Train Loss: 5.8414 || Test Loss: 5.8487
# Epoch 88/5000 || Train Loss: 5.8426 || Test Loss: 5.8318
# Epoch 89/5000 || Train Loss: 5.8346 || Test Loss: 5.8326
# Epoch 90/5000 || Train Loss: 5.8236 || Test Loss: 5.8488
# Epoch 91/5000 || Train Loss: 5.8233 || Test Loss: 5.8211
# Epoch 92/5000 || Train Loss: 5.8310 || Test Loss: 5.7791
# Epoch 93/5000 || Train Loss: 5.8390 || Test Loss: 5.8157
# Epoch 94/5000 || Train Loss: 5.8455 || Test Loss: 5.8221
# Epoch 95/5000 || Train Loss: 5.7943 || Test Loss: 5.8189
# Epoch 96/5000 || Train Loss: 5.8491 || Test Loss: 5.8403
# Epoch 97/5000 || Train Loss: 5.8351 || Test Loss: 5.7881
# Epoch 98/5000 || Train Loss: 5.8005 || Test Loss: 5.8134
# Epoch 99/5000 || Train Loss: 5.8106 || Test Loss: 5.7949
# Epoch 100/5000 || Train Loss: 5.7755 || Test Loss: 5.8116
# Epoch 101/5000 || Train Loss: 5.7974 || Test Loss: 5.8036
# Epoch 102/5000 || Train Loss: 5.7900 || Test Loss: 5.7988
# Epoch 103/5000 || Train Loss: 5.8117 || Test Loss: 5.7830
# Epoch 104/5000 || Train Loss: 5.8134 || Test Loss: 5.7811
# Epoch 105/5000 || Train Loss: 5.8127 || Test Loss: 5.7795
# Epoch 106/5000 || Train Loss: 5.7772 || Test Loss: 5.7827
# Epoch 107/5000 || Train Loss: 5.7875 || Test Loss: 5.7757
# Epoch 108/5000 || Train Loss: 5.7817 || Test Loss: 5.7974
# Epoch 109/5000 || Train Loss: 5.7672 || Test Loss: 5.7905
# Epoch 110/5000 || Train Loss: 5.7829 || Test Loss: 5.7802
# Epoch 111/5000 || Train Loss: 5.7608 || Test Loss: 5.7551
# Epoch 112/5000 || Train Loss: 5.7798 || Test Loss: 5.7772
# Epoch 113/5000 || Train Loss: 5.7446 || Test Loss: 5.7447
# Epoch 114/5000 || Train Loss: 5.7518 || Test Loss: 5.7346
# Epoch 115/5000 || Train Loss: 5.7274 || Test Loss: 5.7557
# Epoch 116/5000 || Train Loss: 5.7577 || Test Loss: 5.7202
# Epoch 117/5000 || Train Loss: 5.7416 || Test Loss: 5.7361
# Epoch 118/5000 || Train Loss: 5.7436 || Test Loss: 5.7331
# Epoch 119/5000 || Train Loss: 5.7432 || Test Loss: 5.7429
# Epoch 120/5000 || Train Loss: 5.7707 || Test Loss: 5.7421
# Epoch 121/5000 || Train Loss: 5.6936 || Test Loss: 5.7420
# Epoch 122/5000 || Train Loss: 5.7723 || Test Loss: 5.7354
# Epoch 123/5000 || Train Loss: 5.7125 || Test Loss: 5.7562
# Epoch 124/5000 || Train Loss: 5.7092 || Test Loss: 5.7111
# Epoch 125/5000 || Train Loss: 5.7086 || Test Loss: 5.7213
# Epoch 126/5000 || Train Loss: 5.7067 || Test Loss: 5.7298
# Epoch 127/5000 || Train Loss: 5.7062 || Test Loss: 5.7105
# Epoch 128/5000 || Train Loss: 5.7170 || Test Loss: 5.7060
# Epoch 129/5000 || Train Loss: 5.6936 || Test Loss: 5.7286
# Epoch 130/5000 || Train Loss: 5.7197 || Test Loss: 5.7346
# Epoch 131/5000 || Train Loss: 5.7311 || Test Loss: 5.7076
# Epoch 132/5000 || Train Loss: 5.6689 || Test Loss: 5.6937
# Epoch 133/5000 || Train Loss: 5.7148 || Test Loss: 5.6751
# Epoch 134/5000 || Train Loss: 5.6891 || Test Loss: 5.6571
# Epoch 135/5000 || Train Loss: 5.6903 || Test Loss: 5.6803
# Epoch 136/5000 || Train Loss: 5.7028 || Test Loss: 5.7004
# Epoch 137/5000 || Train Loss: 5.6925 || Test Loss: 5.7078
# Epoch 138/5000 || Train Loss: 5.6487 || Test Loss: 5.6767
# Epoch 139/5000 || Train Loss: 5.6823 || Test Loss: 5.6777
# Epoch 140/5000 || Train Loss: 5.6350 || Test Loss: 5.6565
# Epoch 141/5000 || Train Loss: 5.6874 || Test Loss: 5.6518
# Epoch 142/5000 || Train Loss: 5.6804 || Test Loss: 5.6509
# Epoch 143/5000 || Train Loss: 5.6775 || Test Loss: 5.6502
# Epoch 144/5000 || Train Loss: 5.6614 || Test Loss: 5.6823
# Epoch 145/5000 || Train Loss: 5.6575 || Test Loss: 5.6260
# Epoch 146/5000 || Train Loss: 5.6521 || Test Loss: 5.6525
# Epoch 147/5000 || Train Loss: 5.6415 || Test Loss: 5.6693
# Epoch 148/5000 || Train Loss: 5.6685 || Test Loss: 5.6438
# Epoch 149/5000 || Train Loss: 5.6424 || Test Loss: 5.6402
# Epoch 150/5000 || Train Loss: 5.6733 || Test Loss: 5.6721
# Epoch 151/5000 || Train Loss: 5.6493 || Test Loss: 5.6405
# Epoch 152/5000 || Train Loss: 5.6159 || Test Loss: 5.6407
# Epoch 153/5000 || Train Loss: 5.6227 || Test Loss: 5.6090
# Epoch 154/5000 || Train Loss: 5.6516 || Test Loss: 5.6344
# Epoch 155/5000 || Train Loss: 5.6468 || Test Loss: 5.6466
# Epoch 156/5000 || Train Loss: 5.6408 || Test Loss: 5.6307
# Epoch 157/5000 || Train Loss: 5.6184 || Test Loss: 5.6256
# Epoch 158/5000 || Train Loss: 5.6772 || Test Loss: 5.6180
# Epoch 159/5000 || Train Loss: 5.6134 || Test Loss: 5.6119
# Epoch 160/5000 || Train Loss: 5.6336 || Test Loss: 5.6336
# Epoch 161/5000 || Train Loss: 5.6282 || Test Loss: 5.6026
# Epoch 162/5000 || Train Loss: 5.5839 || Test Loss: 5.5667
# Epoch 163/5000 || Train Loss: 5.5698 || Test Loss: 5.6162
# Epoch 164/5000 || Train Loss: 5.6029 || Test Loss: 5.5950
# Epoch 165/5000 || Train Loss: 5.5925 || Test Loss: 5.6462
# Epoch 166/5000 || Train Loss: 5.5977 || Test Loss: 5.6065
# Epoch 167/5000 || Train Loss: 5.5759 || Test Loss: 5.5771
# Epoch 168/5000 || Train Loss: 5.5776 || Test Loss: 5.5882
# Epoch 169/5000 || Train Loss: 5.5896 || Test Loss: 5.5833
# Epoch 170/5000 || Train Loss: 5.5667 || Test Loss: 5.6270
# Epoch 171/5000 || Train Loss: 5.5955 || Test Loss: 5.5687
# Epoch 172/5000 || Train Loss: 5.5692 || Test Loss: 5.5876
# Epoch 173/5000 || Train Loss: 5.5804 || Test Loss: 5.5945
# Epoch 174/5000 || Train Loss: 5.5798 || Test Loss: 5.5847
# Epoch 175/5000 || Train Loss: 5.5984 || Test Loss: 5.5599
# Epoch 176/5000 || Train Loss: 5.5760 || Test Loss: 5.5389
# Epoch 177/5000 || Train Loss: 5.5689 || Test Loss: 5.5449
# Epoch 178/5000 || Train Loss: 5.5625 || Test Loss: 5.5617
# Epoch 179/5000 || Train Loss: 5.5569 || Test Loss: 5.5571
# Epoch 180/5000 || Train Loss: 5.5778 || Test Loss: 5.5092
# Epoch 181/5000 || Train Loss: 5.5353 || Test Loss: 5.5540
# Epoch 182/5000 || Train Loss: 5.5613 || Test Loss: 5.4709
# Epoch 183/5000 || Train Loss: 5.5318 || Test Loss: 5.5731
# Epoch 184/5000 || Train Loss: 5.5614 || Test Loss: 5.4730
# Epoch 185/5000 || Train Loss: 5.5383 || Test Loss: 5.5649
# Epoch 186/5000 || Train Loss: 5.5293 || Test Loss: 5.5001
# Epoch 187/5000 || Train Loss: 5.5251 || Test Loss: 5.5304
# Epoch 188/5000 || Train Loss: 5.5535 || Test Loss: 5.5522
# Epoch 189/5000 || Train Loss: 5.5619 || Test Loss: 5.5616
# Epoch 190/5000 || Train Loss: 5.4986 || Test Loss: 5.5596
# Epoch 191/5000 || Train Loss: 5.4916 || Test Loss: 5.4883
# Epoch 192/5000 || Train Loss: 5.4964 || Test Loss: 5.5045
# Epoch 193/5000 || Train Loss: 5.4994 || Test Loss: 5.4836
# Epoch 194/5000 || Train Loss: 5.4965 || Test Loss: 5.4911
# Epoch 195/5000 || Train Loss: 5.4988 || Test Loss: 5.4984
# Epoch 196/5000 || Train Loss: 5.5378 || Test Loss: 5.5129
# Epoch 197/5000 || Train Loss: 5.4939 || Test Loss: 5.4830
# Epoch 198/5000 || Train Loss: 5.4850 || Test Loss: 5.4499
# Epoch 199/5000 || Train Loss: 5.5049 || Test Loss: 5.4208
# Epoch 200/5000 || Train Loss: 5.4466 || Test Loss: 5.4669
# Epoch 201/5000 || Train Loss: 5.4702 || Test Loss: 5.4876
# Epoch 202/5000 || Train Loss: 5.4775 || Test Loss: 5.4864
# Epoch 203/5000 || Train Loss: 5.4437 || Test Loss: 5.4862
# Epoch 204/5000 || Train Loss: 5.4408 || Test Loss: 5.4690
# Epoch 205/5000 || Train Loss: 5.4318 || Test Loss: 5.4460
# Epoch 206/5000 || Train Loss: 5.4696 || Test Loss: 5.4553
# Epoch 207/5000 || Train Loss: 5.4583 || Test Loss: 5.4531
# Epoch 208/5000 || Train Loss: 5.4015 || Test Loss: 5.4517
# Epoch 209/5000 || Train Loss: 5.4793 || Test Loss: 5.4051
# Epoch 210/5000 || Train Loss: 5.4021 || Test Loss: 5.4149
# Epoch 211/5000 || Train Loss: 5.4388 || Test Loss: 5.4172
# Epoch 212/5000 || Train Loss: 5.4146 || Test Loss: 5.4782
# Epoch 213/5000 || Train Loss: 5.4764 || Test Loss: 5.4432
# Epoch 214/5000 || Train Loss: 5.4566 || Test Loss: 5.4003
# Epoch 215/5000 || Train Loss: 5.4015 || Test Loss: 5.4244
# Epoch 216/5000 || Train Loss: 5.4371 || Test Loss: 5.4142
# Epoch 217/5000 || Train Loss: 5.4480 || Test Loss: 5.4813
# Epoch 218/5000 || Train Loss: 5.4650 || Test Loss: 5.4089
# Epoch 219/5000 || Train Loss: 5.4391 || Test Loss: 5.4037
# Epoch 220/5000 || Train Loss: 5.4043 || Test Loss: 5.4386
# Epoch 221/5000 || Train Loss: 5.4054 || Test Loss: 5.3874
# Epoch 222/5000 || Train Loss: 5.4235 || Test Loss: 5.4170
# Epoch 223/5000 || Train Loss: 5.3947 || Test Loss: 5.4058
# Epoch 224/5000 || Train Loss: 5.3567 || Test Loss: 5.4229
# Epoch 225/5000 || Train Loss: 5.4145 || Test Loss: 5.3787
# Epoch 226/5000 || Train Loss: 5.4101 || Test Loss: 5.4241
# Epoch 227/5000 || Train Loss: 5.4055 || Test Loss: 5.3599
# Epoch 228/5000 || Train Loss: 5.4042 || Test Loss: 5.3711
# Epoch 229/5000 || Train Loss: 5.4035 || Test Loss: 5.3373
# Epoch 230/5000 || Train Loss: 5.3244 || Test Loss: 5.3700
# Epoch 231/5000 || Train Loss: 5.4412 || Test Loss: 5.3804
# Epoch 232/5000 || Train Loss: 5.3389 || Test Loss: 5.3574
# Epoch 233/5000 || Train Loss: 5.3540 || Test Loss: 5.3440
# Epoch 234/5000 || Train Loss: 5.3317 || Test Loss: 5.3450
# Epoch 235/5000 || Train Loss: 5.3491 || Test Loss: 5.3831
# Epoch 236/5000 || Train Loss: 5.3695 || Test Loss: 5.3613
# Epoch 237/5000 || Train Loss: 5.3417 || Test Loss: 5.3322
# Epoch 238/5000 || Train Loss: 5.3450 || Test Loss: 5.3452
# Epoch 239/5000 || Train Loss: 5.3401 || Test Loss: 5.3555
# Epoch 240/5000 || Train Loss: 5.4003 || Test Loss: 5.3492
# Epoch 241/5000 || Train Loss: 5.3085 || Test Loss: 5.3543
# Epoch 242/5000 || Train Loss: 5.3330 || Test Loss: 5.3489
# Epoch 243/5000 || Train Loss: 5.3023 || Test Loss: 5.3366
# Epoch 244/5000 || Train Loss: 5.3084 || Test Loss: 5.3000
# Epoch 245/5000 || Train Loss: 5.3243 || Test Loss: 5.3532
# Epoch 246/5000 || Train Loss: 5.2847 || Test Loss: 5.3119
# Epoch 247/5000 || Train Loss: 5.3482 || Test Loss: 5.2888
# Epoch 248/5000 || Train Loss: 5.3399 || Test Loss: 5.2899
# Epoch 249/5000 || Train Loss: 5.2838 || Test Loss: 5.2004
# Epoch 250/5000 || Train Loss: 5.2709 || Test Loss: 5.3028
# Epoch 251/5000 || Train Loss: 5.3211 || Test Loss: 5.2390
# Epoch 252/5000 || Train Loss: 5.3166 || Test Loss: 5.2584
# Epoch 253/5000 || Train Loss: 5.2850 || Test Loss: 5.2651
# Epoch 254/5000 || Train Loss: 5.2640 || Test Loss: 5.3133
# Epoch 255/5000 || Train Loss: 5.3611 || Test Loss: 5.3081
# Epoch 256/5000 || Train Loss: 5.3169 || Test Loss: 5.2660
# Epoch 257/5000 || Train Loss: 5.3146 || Test Loss: 5.2835
# Epoch 258/5000 || Train Loss: 5.2496 || Test Loss: 5.2879
# Epoch 259/5000 || Train Loss: 5.2637 || Test Loss: 5.2479
# Epoch 260/5000 || Train Loss: 5.2428 || Test Loss: 5.2659
# Epoch 261/5000 || Train Loss: 5.2793 || Test Loss: 5.1678
# Epoch 262/5000 || Train Loss: 5.2265 || Test Loss: 5.2018
# Epoch 263/5000 || Train Loss: 5.2377 || Test Loss: 5.2593
# Epoch 264/5000 || Train Loss: 5.2056 || Test Loss: 5.2282
# Epoch 265/5000 || Train Loss: 5.2390 || Test Loss: 5.2387
# Epoch 266/5000 || Train Loss: 5.2266 || Test Loss: 5.2198
# Epoch 267/5000 || Train Loss: 5.2404 || Test Loss: 5.2378
# Epoch 268/5000 || Train Loss: 5.2448 || Test Loss: 5.1887
# Epoch 269/5000 || Train Loss: 5.2093 || Test Loss: 5.2193
# Epoch 270/5000 || Train Loss: 5.1838 || Test Loss: 5.1854
# Epoch 271/5000 || Train Loss: 5.1900 || Test Loss: 5.2499
# Epoch 272/5000 || Train Loss: 5.2618 || Test Loss: 5.1996
# Epoch 273/5000 || Train Loss: 5.2385 || Test Loss: 5.1907
# Epoch 274/5000 || Train Loss: 5.2267 || Test Loss: 5.1793
# Epoch 275/5000 || Train Loss: 5.1587 || Test Loss: 5.1954
# Epoch 276/5000 || Train Loss: 5.2198 || Test Loss: 5.1849
# Epoch 277/5000 || Train Loss: 5.1938 || Test Loss: 5.2261
# Epoch 278/5000 || Train Loss: 5.2211 || Test Loss: 5.1965
# Epoch 279/5000 || Train Loss: 5.1486 || Test Loss: 5.1933
# Epoch 280/5000 || Train Loss: 5.1645 || Test Loss: 5.2028
# Epoch 281/5000 || Train Loss: 5.1190 || Test Loss: 5.1783
# Epoch 282/5000 || Train Loss: 5.1111 || Test Loss: 5.1282
# Epoch 283/5000 || Train Loss: 5.2475 || Test Loss: 5.1890
# Epoch 284/5000 || Train Loss: 5.1362 || Test Loss: 5.2280
# Epoch 285/5000 || Train Loss: 5.1799 || Test Loss: 5.1771
# Epoch 286/5000 || Train Loss: 5.1433 || Test Loss: 5.1829
# Epoch 287/5000 || Train Loss: 5.1090 || Test Loss: 5.1484
# Epoch 288/5000 || Train Loss: 5.1431 || Test Loss: 5.1914
# Epoch 289/5000 || Train Loss: 5.1746 || Test Loss: 5.0925
# Epoch 290/5000 || Train Loss: 5.1866 || Test Loss: 5.1670
# Epoch 291/5000 || Train Loss: 5.1608 || Test Loss: 5.1525
# Epoch 292/5000 || Train Loss: 5.0879 || Test Loss: 5.0312
# Epoch 293/5000 || Train Loss: 5.1583 || Test Loss: 5.0539
# Epoch 294/5000 || Train Loss: 5.1248 || Test Loss: 5.1293
# Epoch 295/5000 || Train Loss: 5.1037 || Test Loss: 5.1111
# Epoch 296/5000 || Train Loss: 5.1223 || Test Loss: 5.0596
# Epoch 297/5000 || Train Loss: 5.1250 || Test Loss: 5.2149
# Epoch 298/5000 || Train Loss: 5.1303 || Test Loss: 5.0898
# Epoch 299/5000 || Train Loss: 5.1976 || Test Loss: 5.1512
# Epoch 300/5000 || Train Loss: 5.1536 || Test Loss: 5.1330
# Epoch 301/5000 || Train Loss: 5.0166 || Test Loss: 5.0848
# Epoch 302/5000 || Train Loss: 5.0587 || Test Loss: 5.0687
# Epoch 303/5000 || Train Loss: 5.0819 || Test Loss: 5.1167
# Epoch 304/5000 || Train Loss: 5.0805 || Test Loss: 5.1164
# Epoch 305/5000 || Train Loss: 5.0867 || Test Loss: 5.0081
# Epoch 306/5000 || Train Loss: 5.1443 || Test Loss: 5.0954
# Epoch 307/5000 || Train Loss: 5.0256 || Test Loss: 4.9628
# Epoch 308/5000 || Train Loss: 5.0820 || Test Loss: 5.0617
# Epoch 309/5000 || Train Loss: 5.0374 || Test Loss: 4.9800
# Epoch 310/5000 || Train Loss: 5.0768 || Test Loss: 5.0276
# Epoch 311/5000 || Train Loss: 5.0176 || Test Loss: 4.9788
# Epoch 312/5000 || Train Loss: 5.0299 || Test Loss: 5.0584
# Epoch 313/5000 || Train Loss: 5.0085 || Test Loss: 5.0895
# Epoch 314/5000 || Train Loss: 5.0328 || Test Loss: 5.0767
# Epoch 315/5000 || Train Loss: 5.0062 || Test Loss: 5.1357
# Epoch 316/5000 || Train Loss: 5.0316 || Test Loss: 5.0670
# Epoch 610/5000 || Train Loss: 4.1558 || Test Loss: 3.9944
# Epoch 611/5000 || Train Loss: 4.0610 || Test Loss: 4.2293
# Epoch 612/5000 || Train Loss: 3.9179 || Test Loss: 3.9645
# Epoch 613/5000 || Train Loss: 4.0660 || Test Loss: 3.9556
# Epoch 614/5000 || Train Loss: 4.0662 || Test Loss: 3.8605
# Epoch 615/5000 || Train Loss: 4.1351 || Test Loss: 4.1467
# Epoch 616/5000 || Train Loss: 3.8997 || Test Loss: 4.0616
# Epoch 617/5000 || Train Loss: 3.9646 || Test Loss: 3.9233
# Epoch 618/5000 || Train Loss: 3.9691 || Test Loss: 4.0123
# Epoch 619/5000 || Train Loss: 3.9661 || Test Loss: 3.9982
# Epoch 620/5000 || Train Loss: 4.0873 || Test Loss: 4.0370
# Epoch 621/5000 || Train Loss: 3.9294 || Test Loss: 3.9274
# Epoch 622/5000 || Train Loss: 3.9644 || Test Loss: 4.0397
# Epoch 623/5000 || Train Loss: 4.0444 || Test Loss: 3.9567
# Epoch 624/5000 || Train Loss: 3.9472 || Test Loss: 4.0876
# Epoch 625/5000 || Train Loss: 3.9815 || Test Loss: 4.1205
# Epoch 626/5000 || Train Loss: 4.0369 || Test Loss: 4.0341
# Epoch 627/5000 || Train Loss: 3.9180 || Test Loss: 3.9345
# Epoch 628/5000 || Train Loss: 3.8725 || Test Loss: 3.9794
# Epoch 629/5000 || Train Loss: 3.9627 || Test Loss: 4.0314
# Epoch 630/5000 || Train Loss: 4.0409 || Test Loss: 3.9067
# Epoch 631/5000 || Train Loss: 3.8305 || Test Loss: 3.9203
# Epoch 632/5000 || Train Loss: 3.9057 || Test Loss: 3.8717
# Epoch 633/5000 || Train Loss: 3.9493 || Test Loss: 3.8869
# Epoch 634/5000 || Train Loss: 3.9409 || Test Loss: 3.9733
# Epoch 635/5000 || Train Loss: 3.9747 || Test Loss: 4.0005
# Epoch 636/5000 || Train Loss: 3.8847 || Test Loss: 3.8553
# Epoch 637/5000 || Train Loss: 3.9256 || Test Loss: 3.9906
# Epoch 638/5000 || Train Loss: 3.7586 || Test Loss: 3.9755
# Epoch 639/5000 || Train Loss: 4.0772 || Test Loss: 3.9019
# Epoch 640/5000 || Train Loss: 3.9084 || Test Loss: 3.9832
# Epoch 641/5000 || Train Loss: 3.9996 || Test Loss: 3.8653
# Epoch 642/5000 || Train Loss: 3.9477 || Test Loss: 4.0349
# Epoch 643/5000 || Train Loss: 3.9652 || Test Loss: 3.9903
# Epoch 644/5000 || Train Loss: 3.9158 || Test Loss: 3.8591
# Epoch 645/5000 || Train Loss: 3.9890 || Test Loss: 3.8086
# Epoch 646/5000 || Train Loss: 3.9075 || Test Loss: 3.9414
# Epoch 647/5000 || Train Loss: 3.9265 || Test Loss: 3.9122
# Epoch 648/5000 || Train Loss: 3.9141 || Test Loss: 3.9201
# Epoch 649/5000 || Train Loss: 3.8852 || Test Loss: 3.8188
# Epoch 650/5000 || Train Loss: 3.8629 || Test Loss: 3.9677
# Epoch 651/5000 || Train Loss: 3.8633 || Test Loss: 3.8350
# Epoch 652/5000 || Train Loss: 3.8659 || Test Loss: 3.8596
# Epoch 653/5000 || Train Loss: 3.8583 || Test Loss: 3.9616
# Epoch 654/5000 || Train Loss: 3.8655 || Test Loss: 3.9711
# Epoch 655/5000 || Train Loss: 3.7907 || Test Loss: 3.8184
# Epoch 656/5000 || Train Loss: 3.8006 || Test Loss: 3.8746
# Epoch 657/5000 || Train Loss: 3.8631 || Test Loss: 3.9872
# Epoch 658/5000 || Train Loss: 3.7853 || Test Loss: 3.7413
# Epoch 659/5000 || Train Loss: 3.8278 || Test Loss: 3.9639
# Epoch 660/5000 || Train Loss: 3.9242 || Test Loss: 3.8208
# Epoch 661/5000 || Train Loss: 3.7959 || Test Loss: 3.9079
# Epoch 662/5000 || Train Loss: 3.9011 || Test Loss: 3.8997
# Epoch 663/5000 || Train Loss: 3.8554 || Test Loss: 3.8534
# Epoch 664/5000 || Train Loss: 3.7351 || Test Loss: 3.7757
# Epoch 665/5000 || Train Loss: 3.8462 || Test Loss: 3.8746
# Epoch 666/5000 || Train Loss: 3.8730 || Test Loss: 3.8252
# Epoch 667/5000 || Train Loss: 3.7853 || Test Loss: 3.8537
# Epoch 668/5000 || Train Loss: 3.9212 || Test Loss: 3.8468
# Epoch 669/5000 || Train Loss: 3.8524 || Test Loss: 3.8180
# Epoch 670/5000 || Train Loss: 3.8062 || Test Loss: 3.8616
# Epoch 671/5000 || Train Loss: 3.6896 || Test Loss: 3.8463
# Epoch 672/5000 || Train Loss: 3.7715 || Test Loss: 3.6966
# Epoch 673/5000 || Train Loss: 3.7225 || Test Loss: 3.8068
# Epoch 674/5000 || Train Loss: 3.7909 || Test Loss: 3.7474
# Epoch 675/5000 || Train Loss: 3.8814 || Test Loss: 3.7459
# Epoch 676/5000 || Train Loss: 3.7913 || Test Loss: 3.9582
# Epoch 677/5000 || Train Loss: 3.7712 || Test Loss: 3.8302
# Epoch 678/5000 || Train Loss: 3.6530 || Test Loss: 3.7955
# Epoch 679/5000 || Train Loss: 3.8955 || Test Loss: 3.7574
# Epoch 680/5000 || Train Loss: 3.9190 || Test Loss: 3.7370
# Epoch 681/5000 || Train Loss: 3.8574 || Test Loss: 3.7624
# Epoch 682/5000 || Train Loss: 3.8071 || Test Loss: 3.8829
# Epoch 683/5000 || Train Loss: 3.7148 || Test Loss: 3.7573
# Epoch 684/5000 || Train Loss: 3.9057 || Test Loss: 3.9073
# Epoch 685/5000 || Train Loss: 3.6982 || Test Loss: 3.7934
# Epoch 686/5000 || Train Loss: 3.9050 || Test Loss: 3.8840
# Epoch 687/5000 || Train Loss: 3.7025 || Test Loss: 3.6808
# Epoch 688/5000 || Train Loss: 3.8403 || Test Loss: 3.7835
# Epoch 689/5000 || Train Loss: 3.7233 || Test Loss: 3.8674
# Epoch 690/5000 || Train Loss: 3.8819 || Test Loss: 3.7182
# Epoch 691/5000 || Train Loss: 3.8124 || Test Loss: 3.8126
# Epoch 692/5000 || Train Loss: 3.7632 || Test Loss: 3.7614
# Epoch 693/5000 || Train Loss: 3.7913 || Test Loss: 3.8410
# Epoch 694/5000 || Train Loss: 3.6883 || Test Loss: 3.8537
# Epoch 695/5000 || Train Loss: 3.8286 || Test Loss: 3.9806
# Epoch 696/5000 || Train Loss: 3.7306 || Test Loss: 3.7442
# Epoch 697/5000 || Train Loss: 3.7693 || Test Loss: 3.7441
# Epoch 698/5000 || Train Loss: 3.7624 || Test Loss: 3.7930
# Epoch 699/5000 || Train Loss: 3.7537 || Test Loss: 3.8048
# Epoch 700/5000 || Train Loss: 3.7177 || Test Loss: 3.8149
# Epoch 701/5000 || Train Loss: 3.7239 || Test Loss: 3.7305
# Epoch 702/5000 || Train Loss: 3.7213 || Test Loss: 3.6909
# Epoch 703/5000 || Train Loss: 3.8278 || Test Loss: 3.7959
# Epoch 704/5000 || Train Loss: 3.7443 || Test Loss: 3.7024
# Epoch 705/5000 || Train Loss: 3.8043 || Test Loss: 3.7075
# Epoch 706/5000 || Train Loss: 3.7334 || Test Loss: 3.7061
# Epoch 707/5000 || Train Loss: 3.7342 || Test Loss: 3.6932
# Epoch 708/5000 || Train Loss: 3.6600 || Test Loss: 3.7066
# Epoch 709/5000 || Train Loss: 3.6812 || Test Loss: 3.8035
# Epoch 710/5000 || Train Loss: 3.8266 || Test Loss: 3.8193
# Epoch 711/5000 || Train Loss: 3.6356 || Test Loss: 3.6344
# Epoch 712/5000 || Train Loss: 3.7061 || Test Loss: 3.7737
# Epoch 713/5000 || Train Loss: 3.6965 || Test Loss: 3.6240
# Epoch 714/5000 || Train Loss: 3.7375 || Test Loss: 3.5976
# Epoch 715/5000 || Train Loss: 3.5657 || Test Loss: 3.7359
# Epoch 716/5000 || Train Loss: 3.5875 || Test Loss: 3.5953
# Epoch 717/5000 || Train Loss: 3.7705 || Test Loss: 3.8195
# Epoch 718/5000 || Train Loss: 3.7848 || Test Loss: 3.7542
# Epoch 719/5000 || Train Loss: 3.8087 || Test Loss: 3.6032
# Epoch 720/5000 || Train Loss: 3.7371 || Test Loss: 3.5971
# Epoch 721/5000 || Train Loss: 3.6567 || Test Loss: 3.6708
# Epoch 722/5000 || Train Loss: 3.6012 || Test Loss: 3.6472
# Epoch 723/5000 || Train Loss: 3.6247 || Test Loss: 3.7337
# Epoch 724/5000 || Train Loss: 3.7227 || Test Loss: 3.6484
# Epoch 725/5000 || Train Loss: 3.7074 || Test Loss: 3.6034
# Epoch 726/5000 || Train Loss: 3.5613 || Test Loss: 3.6397
# Epoch 727/5000 || Train Loss: 3.6615 || Test Loss: 3.6547
# Epoch 728/5000 || Train Loss: 3.5470 || Test Loss: 3.6765
# Epoch 729/5000 || Train Loss: 3.6756 || Test Loss: 3.6739
# Epoch 730/5000 || Train Loss: 3.7934 || Test Loss: 3.7589
# Epoch 731/5000 || Train Loss: 3.4663 || Test Loss: 3.7579
# Epoch 732/5000 || Train Loss: 3.6674 || Test Loss: 3.6902
# Epoch 733/5000 || Train Loss: 3.5640 || Test Loss: 3.6176
# Epoch 734/5000 || Train Loss: 3.6469 || Test Loss: 3.6971
# Epoch 735/5000 || Train Loss: 3.6138 || Test Loss: 3.6893
# Epoch 736/5000 || Train Loss: 3.7194 || Test Loss: 3.5989
# Epoch 737/5000 || Train Loss: 3.6558 || Test Loss: 3.5632
# Epoch 738/5000 || Train Loss: 3.7179 || Test Loss: 3.5752
# Epoch 739/5000 || Train Loss: 3.5698 || Test Loss: 3.6100
# Epoch 740/5000 || Train Loss: 3.7194 || Test Loss: 3.5914
# Epoch 741/5000 || Train Loss: 3.6416 || Test Loss: 3.6625
# Epoch 742/5000 || Train Loss: 3.6240 || Test Loss: 3.6729
# Epoch 743/5000 || Train Loss: 3.5672 || Test Loss: 3.7151
# Epoch 744/5000 || Train Loss: 3.6075 || Test Loss: 3.6256
# Epoch 745/5000 || Train Loss: 3.6765 || Test Loss: 3.6412
# Epoch 746/5000 || Train Loss: 3.5013 || Test Loss: 3.6194
# Epoch 747/5000 || Train Loss: 3.7098 || Test Loss: 3.6529
# Epoch 748/5000 || Train Loss: 3.6224 || Test Loss: 3.6549
# Epoch 749/5000 || Train Loss: 3.5423 || Test Loss: 3.6124
# Epoch 750/5000 || Train Loss: 3.5586 || Test Loss: 3.4150
# Epoch 751/5000 || Train Loss: 3.5727 || Test Loss: 3.4339
# Epoch 752/5000 || Train Loss: 3.6925 || Test Loss: 3.5591
# Epoch 753/5000 || Train Loss: 3.6372 || Test Loss: 3.5754
# Epoch 754/5000 || Train Loss: 3.6342 || Test Loss: 3.5948
# Epoch 755/5000 || Train Loss: 3.4982 || Test Loss: 3.6020
# Epoch 756/5000 || Train Loss: 3.4577 || Test Loss: 3.4992
# Epoch 757/5000 || Train Loss: 3.5784 || Test Loss: 3.4400
# Epoch 758/5000 || Train Loss: 3.6575 || Test Loss: 3.5364
# Epoch 759/5000 || Train Loss: 3.4625 || Test Loss: 3.4407
# Epoch 760/5000 || Train Loss: 3.5719 || Test Loss: 3.5177
# Epoch 761/5000 || Train Loss: 3.5814 || Test Loss: 3.5858
# Epoch 762/5000 || Train Loss: 3.5803 || Test Loss: 3.5242
# Epoch 763/5000 || Train Loss: 3.5833 || Test Loss: 3.5742
# Epoch 764/5000 || Train Loss: 3.5516 || Test Loss: 3.5199
# Epoch 765/5000 || Train Loss: 3.5640 || Test Loss: 3.4871
# Epoch 766/5000 || Train Loss: 3.6826 || Test Loss: 3.5302
# Epoch 767/5000 || Train Loss: 3.6272 || Test Loss: 3.6322
# Epoch 768/5000 || Train Loss: 3.3921 || Test Loss: 3.5626
# Epoch 769/5000 || Train Loss: 3.5834 || Test Loss: 3.3668
# Epoch 770/5000 || Train Loss: 3.6555 || Test Loss: 3.4463
# Epoch 771/5000 || Train Loss: 3.5673 || Test Loss: 3.4631
# Epoch 772/5000 || Train Loss: 3.6040 || Test Loss: 3.6104
# Epoch 773/5000 || Train Loss: 3.5632 || Test Loss: 3.5921
# Epoch 774/5000 || Train Loss: 3.3955 || Test Loss: 3.4521
# Epoch 775/5000 || Train Loss: 3.4760 || Test Loss: 3.5845
# Epoch 776/5000 || Train Loss: 3.6128 || Test Loss: 3.4632
# Epoch 777/5000 || Train Loss: 3.6188 || Test Loss: 3.4262
# Epoch 778/5000 || Train Loss: 3.5151 || Test Loss: 3.5327
# Epoch 779/5000 || Train Loss: 3.4772 || Test Loss: 3.3359
# Epoch 780/5000 || Train Loss: 3.5000 || Test Loss: 3.4801
# Epoch 781/5000 || Train Loss: 3.5502 || Test Loss: 3.4097
# Epoch 782/5000 || Train Loss: 3.3472 || Test Loss: 3.4368
# Epoch 783/5000 || Train Loss: 3.6095 || Test Loss: 3.4748
# Epoch 784/5000 || Train Loss: 3.5431 || Test Loss: 3.6261
# Epoch 785/5000 || Train Loss: 3.4943 || Test Loss: 3.4932
# Epoch 786/5000 || Train Loss: 3.3502 || Test Loss: 3.4145
# Epoch 787/5000 || Train Loss: 3.4269 || Test Loss: 3.3210
# Epoch 788/5000 || Train Loss: 3.4682 || Test Loss: 3.5209
# Epoch 789/5000 || Train Loss: 3.5011 || Test Loss: 3.3790
# Epoch 790/5000 || Train Loss: 3.5362 || Test Loss: 3.4460
# Epoch 791/5000 || Train Loss: 3.5073 || Test Loss: 3.3833
# Epoch 792/5000 || Train Loss: 3.6169 || Test Loss: 3.3279
# Epoch 793/5000 || Train Loss: 3.4958 || Test Loss: 3.3793
# Epoch 794/5000 || Train Loss: 3.4415 || Test Loss: 3.4029
# Epoch 795/5000 || Train Loss: 3.4680 || Test Loss: 3.5267
# Epoch 796/5000 || Train Loss: 3.4865 || Test Loss: 3.4220
# Epoch 797/5000 || Train Loss: 3.4944 || Test Loss: 3.3746
# Epoch 798/5000 || Train Loss: 3.4766 || Test Loss: 3.3670
# Epoch 799/5000 || Train Loss: 3.4019 || Test Loss: 3.5773
# Epoch 800/5000 || Train Loss: 3.4655 || Test Loss: 3.5420
# Epoch 801/5000 || Train Loss: 3.3020 || Test Loss: 3.3449
# Epoch 802/5000 || Train Loss: 3.5010 || Test Loss: 3.5440
# Epoch 803/5000 || Train Loss: 3.5055 || Test Loss: 3.4113
# Epoch 804/5000 || Train Loss: 3.4895 || Test Loss: 3.4912
# Epoch 805/5000 || Train Loss: 3.3731 || Test Loss: 3.5066
# Epoch 806/5000 || Train Loss: 3.3199 || Test Loss: 3.5317
# Epoch 807/5000 || Train Loss: 3.4957 || Test Loss: 3.3822
# Epoch 808/5000 || Train Loss: 3.4122 || Test Loss: 3.4457
# Epoch 809/5000 || Train Loss: 3.4744 || Test Loss: 3.5354
# Epoch 810/5000 || Train Loss: 3.2277 || Test Loss: 3.3541
# Epoch 811/5000 || Train Loss: 3.4745 || Test Loss: 3.4461
# Epoch 812/5000 || Train Loss: 3.2475 || Test Loss: 3.3302
# Epoch 813/5000 || Train Loss: 3.2972 || Test Loss: 3.3541
# Epoch 814/5000 || Train Loss: 3.4466 || Test Loss: 3.4089
# Epoch 815/5000 || Train Loss: 3.4672 || Test Loss: 3.4786
# Epoch 816/5000 || Train Loss: 3.4593 || Test Loss: 3.4757
# Epoch 817/5000 || Train Loss: 3.4412 || Test Loss: 3.4608
# Epoch 818/5000 || Train Loss: 3.4196 || Test Loss: 3.2840
# Epoch 4848/5000 || Train Loss: 0.0680 || Test Loss: 0.0683
# Epoch 4849/5000 || Train Loss: 0.0626 || Test Loss: 0.0662
# Epoch 4850/5000 || Train Loss: 0.0647 || Test Loss: 0.0668
# Epoch 4851/5000 || Train Loss: 0.0649 || Test Loss: 0.0633
# Epoch 4852/5000 || Train Loss: 0.0667 || Test Loss: 0.0655
# Epoch 4853/5000 || Train Loss: 0.0714 || Test Loss: 0.0683
# Epoch 4854/5000 || Train Loss: 0.0659 || Test Loss: 0.0645
# Epoch 4855/5000 || Train Loss: 0.0653 || Test Loss: 0.0671
# Epoch 4856/5000 || Train Loss: 0.0660 || Test Loss: 0.0648
# Epoch 4857/5000 || Train Loss: 0.0670 || Test Loss: 0.0687
# Epoch 4858/5000 || Train Loss: 0.0667 || Test Loss: 0.0636
# Epoch 4859/5000 || Train Loss: 0.0680 || Test Loss: 0.0681
# Epoch 4860/5000 || Train Loss: 0.0645 || Test Loss: 0.0654
# Epoch 4861/5000 || Train Loss: 0.0665 || Test Loss: 0.0664
# Epoch 4862/5000 || Train Loss: 0.0747 || Test Loss: 0.0698
# Epoch 4863/5000 || Train Loss: 0.0697 || Test Loss: 0.0668
# Epoch 4864/5000 || Train Loss: 0.0680 || Test Loss: 0.0674
# Epoch 4865/5000 || Train Loss: 0.0664 || Test Loss: 0.0680
# Epoch 4866/5000 || Train Loss: 0.0665 || Test Loss: 0.0633
# Epoch 4867/5000 || Train Loss: 0.0655 || Test Loss: 0.0712
# Epoch 4868/5000 || Train Loss: 0.0637 || Test Loss: 0.0642
# Epoch 4869/5000 || Train Loss: 0.0685 || Test Loss: 0.0655
# Epoch 4870/5000 || Train Loss: 0.0681 || Test Loss: 0.0639
# Epoch 4871/5000 || Train Loss: 0.0693 || Test Loss: 0.0660
# Epoch 4872/5000 || Train Loss: 0.0709 || Test Loss: 0.0726
# Epoch 4873/5000 || Train Loss: 0.0700 || Test Loss: 0.0678
# Epoch 4874/5000 || Train Loss: 0.0689 || Test Loss: 0.0685
# Epoch 4875/5000 || Train Loss: 0.0655 || Test Loss: 0.0654
# Epoch 4876/5000 || Train Loss: 0.0651 || Test Loss: 0.0696
# Epoch 4877/5000 || Train Loss: 0.0646 || Test Loss: 0.0697
# Epoch 4878/5000 || Train Loss: 0.0655 || Test Loss: 0.0677
# Epoch 4879/5000 || Train Loss: 0.0650 || Test Loss: 0.0588
# Epoch 4880/5000 || Train Loss: 0.0645 || Test Loss: 0.0652
# Epoch 4881/5000 || Train Loss: 0.0711 || Test Loss: 0.0663
# Epoch 4882/5000 || Train Loss: 0.0636 || Test Loss: 0.0644
# Epoch 4883/5000 || Train Loss: 0.0654 || Test Loss: 0.0658
# Epoch 4884/5000 || Train Loss: 0.0686 || Test Loss: 0.0652
# Epoch 4885/5000 || Train Loss: 0.0666 || Test Loss: 0.0657
# Epoch 4886/5000 || Train Loss: 0.0719 || Test Loss: 0.0639
# Epoch 4887/5000 || Train Loss: 0.0699 || Test Loss: 0.0656
# Epoch 4888/5000 || Train Loss: 0.0656 || Test Loss: 0.0651
# Epoch 4970/5000 || Train Loss: 0.0623 || Test Loss: 0.0620
# Epoch 4971/5000 || Train Loss: 0.0600 || Test Loss: 0.0657
# Epoch 4972/5000 || Train Loss: 0.0642 || Test Loss: 0.0667
# Epoch 4973/5000 || Train Loss: 0.0667 || Test Loss: 0.0616
# Epoch 4974/5000 || Train Loss: 0.0636 || Test Loss: 0.0615
# Epoch 4975/5000 || Train Loss: 0.0750 || Test Loss: 0.0635
# Epoch 4976/5000 || Train Loss: 0.0606 || Test Loss: 0.0641
# Epoch 4977/5000 || Train Loss: 0.0648 || Test Loss: 0.0622
# Epoch 4978/5000 || Train Loss: 0.0679 || Test Loss: 0.0611
# Epoch 4979/5000 || Train Loss: 0.0658 || Test Loss: 0.0662
# Epoch 4980/5000 || Train Loss: 0.0655 || Test Loss: 0.0620
# Epoch 4981/5000 || Train Loss: 0.0606 || Test Loss: 0.0633
# Epoch 4982/5000 || Train Loss: 0.0588 || Test Loss: 0.0646
# Epoch 4983/5000 || Train Loss: 0.0640 || Test Loss: 0.0632
# Epoch 4984/5000 || Train Loss: 0.0648 || Test Loss: 0.0595
# Epoch 4985/5000 || Train Loss: 0.0626 || Test Loss: 0.0720
# Epoch 4986/5000 || Train Loss: 0.0597 || Test Loss: 0.0672
# Epoch 4987/5000 || Train Loss: 0.0681 || Test Loss: 0.0600
# Epoch 4988/5000 || Train Loss: 0.0611 || Test Loss: 0.0652
# Epoch 4989/5000 || Train Loss: 0.0621 || Test Loss: 0.0663
# Epoch 4990/5000 || Train Loss: 0.0593 || Test Loss: 0.0605
# Epoch 4991/5000 || Train Loss: 0.0660 || Test Loss: 0.0653
# Epoch 4992/5000 || Train Loss: 0.0622 || Test Loss: 0.0608
# Epoch 4993/5000 || Train Loss: 0.0584 || Test Loss: 0.0652
# Epoch 4994/5000 || Train Loss: 0.0602 || Test Loss: 0.0651
# Epoch 4995/5000 || Train Loss: 0.0623 || Test Loss: 0.0666
# Epoch 4996/5000 || Train Loss: 0.0652 || Test Loss: 0.0689
# Epoch 4997/5000 || Train Loss: 0.0612 || Test Loss: 0.0647
# Epoch 4998/5000 || Train Loss: 0.0655 || Test Loss: 0.0610
# Epoch 4999/5000 || Train Loss: 0.0623 || Test Loss: 0.0668
# Epoch 5000/5000 || Train Loss: 0.0652 || Test Loss: 0.0679
# Training Complete.

# %%
## Test Predictive Accuracy
def test_cbow(test_data, model, sample_size=None, seed=42, use_gpu=False):
    ## Random State
    np.random.seed(seed)
    ## Count Correct Answers
    correct_ct = 0
    ## Downsample if Desired (To Save Time)
    if sample_size is None:
        sample = test_data
    else:
        sample = np.random.choice(len(test_data), sample_size, replace=False)
        sample = [test_data[s] for s in sample]
    ## Evaluate
    model.eval()
    for ctx_var, target in get_cbow_batches(sample, 1):
        if use_gpu:
            ctx_var = ctx_var.cuda()
        model.zero_grad()
        log_probs = model(ctx_var)
        if use_gpu:
            log_probs = log_probs.cpu()
        _, predicted = torch.max(log_probs.data, 1)
        if torch.eq(predicted, target[0]):
            correct_ct += 1

    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(sample)*100, correct_ct, len(sample)))

test_cbow(cbow_train, cbow_model, sample_size=min(5000, len(cbow_train)), use_gpu=torch.cuda.is_available())
test_cbow(cbow_test, cbow_model, sample_size=min(5000, len(cbow_test)), use_gpu=torch.cuda.is_available())
# Out:
# <ipython-input-14-e0a2613bcaff>:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.log_softmax(out)
# Accuracy: 99.8% (1088/1090)
# Accuracy: 99.8% (1088/1090)

# %%
showPlot('CBOW Losses',cbow_losses,cbow_test_losses)

# %% [markdown]
# ## Skip-gram Implementation

# %% [markdown]
# We've now trained an embedding using the continuous bag of words model. Below, we also show code for training the opposite model - the skipgram model - where you predict the context words based on a target word.
#
# Note how simple the SkipGram network is. There are no linear layers - just the embedding layer, and the training simply aims to maximize the dot product of embeddings of the target and embedding words.

# %% [markdown]
# #### Dataset Generation
#
# We provide the beginning of a function for generating the skipgram dataset. You need to implement negative sampling.

# %%
# Tuple of a word (the target) to a word (a context word)
def create_skipgram_dataset(documents, context_size, k_negative=5):
    data = []
    for document in documents:
        document = ["EOS"] * context_size + document + ["EOS"] * context_size
        for i in range(context_size, len(document) - context_size):
            for j in range(1, context_size+1):
                data.append((document[i], document[i-j], 1))
                data.append((document[i], document[i+j], 1))

            ##TODO: Implement negative sampling
            for _ in range(k_negative):
                if (random.random() < 0.5 and i > context_size) or (i >= len(document) - context_size - 1):
                    idx = random.randint(0, i - context_size - 1)
                else:
                    idx = random.randint(i+context_size+1, len(document)-1)
                data.append((document[i], document[idx], 0))
    return data

## Create Datasets
skipgram_train = create_skipgram_dataset(documents_train, context_size=CONTEXT_SIZE, k_negative=5)
skipgram_test = create_skipgram_dataset(documents_test, context_size=CONTEXT_SIZE, k_negative=5)

## Show Samples
print('skipgram sample', skipgram_train[:10])
# Out:
# skipgram sample [('once', 'EOS', 1), ('once', 'upon', 1), ('once', 'EOS', 1), ('once', 'a', 1), ('once', 'my', 0), ('once', 'curtain', 0), ('once', 'the', 0), ('once', 'burden', 0), ('once', 'of', 0), ('upon', 'once', 1)]

# %%
## Create Batches
def get_sgram_batches(data, batch_size):
    """

    """
    indices = np.arange(len(data))
    np.random.shuffle(indices)
    current_batch = []
    for i, indice in enumerate(indices):
        in_w, out_w, target = data[indice]
        in_w_var = torch.LongTensor([w2i[in_w]])
        out_w_var = torch.LongTensor([w2i[out_w]])
        target_t = torch.Tensor([target])
        current_batch.append((in_w_var, out_w_var, target_t))
        if current_batch and len(current_batch) % batch_size == 0 or i == len(indices) - 1:
            batch_in_w_var = torch.stack([v[0] for v in current_batch])
            batch_out_w_var = torch.stack([v[1] for v in current_batch])
            batch_target = torch.stack([v[2] for v in current_batch])
            current_batch = []
            yield batch_in_w_var, batch_out_w_var, batch_target

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embd_size):
        super(SkipGram, self).__init__()
        #TODO implement layers shown in the picture above
        self.vocab_size = vocab_size
        self.embd_size = embd_size

        self.embedding = nn.Embedding(vocab_size, embd_size)
        self.sigmoid = nn.Sigmoid()


    def forward(self, focus, context):
        #TODO implement forward of SkipGram.
        focus_embd = self.embedding(focus).view((-1, 1, self.embd_size))
        context_embd = self.embedding(context).view((-1, self.embd_size, 1))
        out = F.logsigmoid(torch.bmm(focus_embd, context_embd).view(1,-1))

        return out

# %%
def train_skipgram(train_data,
                   test_data,
                   model=None,
                   n_epoch=30,
                   learning_rate=0.01,
                   batch_size=1,
                   embd_size=128,
                   print_every_step=None,
                   print_every_epoch=1,
                   random_seed=1):
    """

    """
    ## Set Random Seed
    torch.manual_seed(random_seed)
    ## Initialize Model
    if model is None:
        model = SkipGram(vocab_size, embd_size)
    ## Put on GPU
    if torch.cuda.is_available():
        model = model.cuda()
    ## Show Model
    print(model)
    ## Initialize Optimizer
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    ##TODO: Choose the appropriate Loss Function
    loss_fn = nn.MSELoss()
    ## Loss Cache
    losses = []
    test_losses = []
    ## Training Loop
    for epoch in range(n_epoch):
        total_loss = .0
        counter = 0
        model.train()
        for step, (in_w_var, out_w_var, target_t) in enumerate(get_sgram_batches(train_data, batch_size)):
            #TODO implement training procedure for SkipGram
            if torch.cuda.is_available():
              in_w_var = in_w_var.cuda()
              out_w_var = out_w_var.cuda()
              target_t = target_t.cuda()
            target_t = target_t.view((1,-1))[0]
            counter += 1
            model.zero_grad()
            out = model(in_w_var, out_w_var)
            loss = loss_fn(out,target_t)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            if print_every_step is not None and (step + 1) % print_every_step == 0:
                print("Epoch {} || Step {}/{} || Loss: {:.4f}".format(epoch+1, step+1, len(train_data), (total_loss / step+1)))

        if print_every_epoch is not None and (epoch + 1) % print_every_epoch == 0:
            print("Epoch {}/{} || Loss: {:.4f}".format(epoch+1, n_epoch, total_loss / (step + 1)))
        ##TODO Compute Losses
        train_loss = total_loss/counter
        test_loss = 0
        model.eval()
        with torch.no_grad():
          counter = 0
          for step, (in_w_var, out_w_var, target_t) in enumerate(get_sgram_batches(test_data, batch_size)):
            if torch.cuda.is_available():
              in_w_var = in_w_var.cuda()
              out_w_var = out_w_var.cuda()
              target_t = target_t.cuda()
            target_t = target_t.view((1,-1))[0]
            counter += 1
            out = model(in_w_var, out_w_var)
            loss = loss_fn(out,target_t)
            test_loss += loss.item()
        test_loss = test_loss/counter
        losses.append(train_loss)
        test_losses.append(test_loss)
    print("Training Complete")
    return model, losses

## Fit Model
sg_model, sg_losses = train_skipgram(skipgram_train,
                                     skipgram_test,
                                     n_epoch=1000,
                                     learning_rate=0.5,
                                     batch_size=len(skipgram_train),
                                     embd_size=128,
                                     print_every_step=None,
                                     print_every_epoch=10)
# Out:
# SkipGram(
#   (embedding): Embedding(435, 128)
#   (sigmoid): Sigmoid()
# )
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([9810])) that is different to the input size (torch.Size([1, 9810])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 10/1000 || Loss: 24.2143
# Epoch 20/1000 || Loss: 11.6569
# Epoch 30/1000 || Loss: 6.5170
# Epoch 40/1000 || Loss: 4.0174
# Epoch 50/1000 || Loss: 2.6741
# Epoch 60/1000 || Loss: 1.9029
# Epoch 70/1000 || Loss: 1.4403
# Epoch 80/1000 || Loss: 1.1535
# Epoch 90/1000 || Loss: 0.9702
# Epoch 100/1000 || Loss: 0.8494
# Epoch 110/1000 || Loss: 0.7671
# Epoch 120/1000 || Loss: 0.7090
# Epoch 130/1000 || Loss: 0.6668
# Epoch 140/1000 || Loss: 0.6352
# Epoch 150/1000 || Loss: 0.6109
# Epoch 160/1000 || Loss: 0.5917
# Epoch 170/1000 || Loss: 0.5763
# Epoch 180/1000 || Loss: 0.5636
# Epoch 190/1000 || Loss: 0.5531
# Epoch 200/1000 || Loss: 0.5442
# Epoch 210/1000 || Loss: 0.5367
# Epoch 220/1000 || Loss: 0.5301
# Epoch 230/1000 || Loss: 0.5244
# Epoch 240/1000 || Loss: 0.5194
# Epoch 250/1000 || Loss: 0.5150
# Epoch 260/1000 || Loss: 0.5111
# Epoch 270/1000 || Loss: 0.5076
# Epoch 280/1000 || Loss: 0.5044
# Epoch 290/1000 || Loss: 0.5015
# Epoch 300/1000 || Loss: 0.4989
# Epoch 310/1000 || Loss: 0.4965
# Epoch 320/1000 || Loss: 0.4943
# Epoch 330/1000 || Loss: 0.4923
# Epoch 340/1000 || Loss: 0.4904
# Epoch 350/1000 || Loss: 0.4887
# Epoch 360/1000 || Loss: 0.4871
# Epoch 370/1000 || Loss: 0.4856
# Epoch 380/1000 || Loss: 0.4842
# Epoch 390/1000 || Loss: 0.4829
# Epoch 400/1000 || Loss: 0.4817
# Epoch 410/1000 || Loss: 0.4805
# Epoch 420/1000 || Loss: 0.4795
# Epoch 430/1000 || Loss: 0.4784
# Epoch 440/1000 || Loss: 0.4775
# Epoch 450/1000 || Loss: 0.4766
# Epoch 460/1000 || Loss: 0.4757
# Epoch 470/1000 || Loss: 0.4749
# Epoch 480/1000 || Loss: 0.4741
# Epoch 490/1000 || Loss: 0.4734
# Epoch 500/1000 || Loss: 0.4727
# Epoch 510/1000 || Loss: 0.4720
# Epoch 520/1000 || Loss: 0.4714
# Epoch 530/1000 || Loss: 0.4708
# Epoch 540/1000 || Loss: 0.4702
# Epoch 550/1000 || Loss: 0.4697
# Epoch 560/1000 || Loss: 0.4691
# Epoch 570/1000 || Loss: 0.4686
# Epoch 580/1000 || Loss: 0.4681
# Epoch 590/1000 || Loss: 0.4676
# Epoch 600/1000 || Loss: 0.4672
# Epoch 610/1000 || Loss: 0.4668
# Epoch 620/1000 || Loss: 0.4663
# Epoch 630/1000 || Loss: 0.4659
# Epoch 640/1000 || Loss: 0.4655
# Epoch 650/1000 || Loss: 0.4652
# Epoch 660/1000 || Loss: 0.4648
# Epoch 670/1000 || Loss: 0.4645
# Epoch 680/1000 || Loss: 0.4641
# Epoch 690/1000 || Loss: 0.4638
# Epoch 700/1000 || Loss: 0.4635
# Epoch 710/1000 || Loss: 0.4632
# Epoch 720/1000 || Loss: 0.4629
# Epoch 730/1000 || Loss: 0.4626
# Epoch 740/1000 || Loss: 0.4623
# Epoch 750/1000 || Loss: 0.4620
# Epoch 760/1000 || Loss: 0.4618
# Epoch 770/1000 || Loss: 0.4615
# Epoch 780/1000 || Loss: 0.4613
# Epoch 790/1000 || Loss: 0.4610
# Epoch 800/1000 || Loss: 0.4608
# Epoch 810/1000 || Loss: 0.4606
# Epoch 820/1000 || Loss: 0.4604
# Epoch 830/1000 || Loss: 0.4601
# Epoch 840/1000 || Loss: 0.4599
# Epoch 850/1000 || Loss: 0.4597
# Epoch 860/1000 || Loss: 0.4595
# Epoch 870/1000 || Loss: 0.4593
# Epoch 880/1000 || Loss: 0.4591
# Epoch 890/1000 || Loss: 0.4590
# Epoch 900/1000 || Loss: 0.4588
# Epoch 910/1000 || Loss: 0.4586
# Epoch 920/1000 || Loss: 0.4584
# Epoch 930/1000 || Loss: 0.4583
# Epoch 940/1000 || Loss: 0.4581
# Epoch 950/1000 || Loss: 0.4579
# Epoch 960/1000 || Loss: 0.4578
# Epoch 970/1000 || Loss: 0.4576
# Epoch 980/1000 || Loss: 0.4575
# Epoch 990/1000 || Loss: 0.4573
# Epoch 1000/1000 || Loss: 0.4572
# Training Complete

# %%
## Plot Losses
showPlot('SkipGram Losses', sg_losses)

# %%
## Evaluate Accuracy
def test_skipgram(test_data, model):
    correct_ct = 0
    for in_w_var, out_w_var, target_t in get_sgram_batches(test_data, 1):

        if torch.cuda.is_available():
            in_w_var = in_w_var.cuda()
            out_w_var = out_w_var.cuda()
            target_t = target_t.cuda()
        probs = model(in_w_var, out_w_var)
        predicted = (probs > 0.5)
        correct_ct += torch.sum(torch.eq(predicted[0], target_t))

    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(test_data)*100, correct_ct, len(test_data)))

test_skipgram(skipgram_train, sg_model)
test_skipgram(skipgram_test, sg_model)
# Out:
# Accuracy: 55.6% (5450/9810)
# Accuracy: 55.6% (5450/9810)

# %% [markdown]
# ### Semantic Similarity
# You are asked to write 2 functions. The first function `get_similarity` takes two terms in the vocabulary as arguments and returns their semantic similarity (cosine similarity). The second function `show_similar_terms` takes as an argument a term in the vocabulary and shows the top_k most similar terms based on cosine similarity. Use your functions to evaluate similarity of words in the Raven (based on your trained model) and some general words in the pretrained corpus.
#
# *Note:* Typically, word embeddings are typically trained on much larger datasets than the ones we provide. You will not necessarily see interpretable similarities below. We are primarily interested in your implementation. Accordingly, we provide code that loads pretrained word embeddings learned using 27 billion tweets. Learn more here: https://nlp.stanford.edu/projects/glove/

# %%
## Load Pretrained Vectors
glove_vectors = gensim.downloader.load('glove-twitter-25')

## Extract Embeddings and Vocab
glove_vocab = glove_vectors.index_to_key ## Note: If this doesn't work because of version < 4.0, use .index_to_key
glove_w2i = {w : i for i, w in enumerate(glove_vocab)}
glove_i2w = {i : w for i, w in enumerate(glove_vocab)}

## Convert Embeddings
glove_embeddings = nn.Embedding(len(glove_vocab), 25).cuda()
glove_embeddings = glove_embeddings.from_pretrained(torch.Tensor(glove_vectors.vectors)).cuda()
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
def get_similarity(embeddings,
                   w2i,
                   term1,
                   term2):
    """

    """
    ## Check Terms
    for term in [term1, term2]:
        if term not in w2i:
            raise KeyError(f"Term `{term}` not found")
    ## Get Indices
    term1_ind = torch.LongTensor([w2i[term1]]).cuda()
    term2_ind = torch.LongTensor([w2i[term2]]).cuda()
    ##TODO: Retrieve Embeddings and Compute Cosine Similarity

    distance = F.cosine_similarity(embeddings(term1_ind),embeddings(term2_ind)).item()
    print(term1, term2, distance)


def show_similar_terms(embeddings,
                       w2i,
                       i2w,
                       target_term,
                       top_k=10):
    """

    """
    ## Get Target Vector
    if target_term not in w2i:
        raise KeyError(f"Term `{target_term}` not in vocabulary")
    target_ind = torch.LongTensor([w2i[target_term]]).cuda()
    ##TODO: Retrieve Embeddings for Target Term and Full Vocabulary
    ## Print out the top_k most similar terms based on cosine similarity
    sim_list = []
    for word in w2i:
      ind = torch.LongTensor([w2i[word]]).cuda()
      sim = F.cosine_similarity(embeddings(ind), embeddings(target_ind))
      sim_list.append((sim, word))
    sim_list.sort(reverse=True)
    top_terms = [sim_list[i][1] for i in range(top_k)]
    print(top_terms)

# %% [markdown]
# #### Evaluation
#
# First, evaluate similarity for embeddings trained using The Raven snippet. Then evaluate similarity in the pretrained embeddings.

# %%
get_similarity(cbow_model.embedding, w2i, "raven", "door")
# Out:
# raven door 0.03028169274330139

# %%
## Evaluation for The Raven embeddings
get_similarity(cbow_model.embedding, w2i, "raven","nevermore")
get_similarity(cbow_model.embedding, w2i, "raven", "door")
show_similar_terms(cbow_model.embedding, w2i, i2w, "raven")

## Evaluation for The Raven Skipgram embeddings
get_similarity(sg_model.embedding, w2i, "raven","nevermore")
get_similarity(sg_model.embedding, w2i, "raven", "door")
show_similar_terms(sg_model.embedding, w2i, i2w, "raven")
# Out:
# raven nevermore 0.06675350666046143
# raven door 0.03028169274330139
# ['raven', 'hope', 'god', 'him', 'sign', 'from', 'ah', 'beating', 'rustling', 'is']
# raven nevermore 0.06278024613857269
# raven door 0.08209915459156036
# ['raven', 'wished', 'feather', 'desert', 'rare', 'faintly', 'bust', 'be', 'craven', 'syllable']

# %%
## Evaluation for Glove Embeddings
get_similarity(glove_embeddings, glove_w2i, "mouse","computer")
get_similarity(glove_embeddings, glove_w2i, "mouse","cat")
get_similarity(glove_embeddings, glove_w2i, "mouse","dog")
get_similarity(glove_embeddings, glove_w2i, "cat","dog")
show_similar_terms(glove_embeddings, glove_w2i, glove_i2w, "cat")
# Out:
# mouse computer 0.695428729057312
# mouse cat 0.8381087183952332
# mouse dog 0.760636568069458
# cat dog 0.9590820074081421
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-8a10ef15302f> in <cell line: 6>()
#       4 get_similarity(glove_embeddings, glove_w2i, "mouse","dog")
#       5 get_similarity(glove_embeddings, glove_w2i, "cat","dog")
# ----> 6 show_similar_terms(glove_embeddings, glove_w2i, glove_i2w, "cat")
#
# <ipython-input-25-6a94bf75862d> in show_similar_terms(embeddings, w2i, i2w, target_term, top_k)
#      38       sim = F.cosine_similarity(embeddings(ind), embeddings(target_ind))
#      39       sim_list.append((sim, word))
# ---> 40     sim_list.sort(reverse=True)
#      41     top_terms = [sim_list[i][1] for i in range(top_k)]
#      42     print(top_terms)
#
# KeyboardInterrupt:
